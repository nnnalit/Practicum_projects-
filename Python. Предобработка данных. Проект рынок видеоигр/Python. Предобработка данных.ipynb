# %% [markdown]
# <font color='DarkBlue' size=+2><b>Комментарий ревьюера</b></font><br>
# <font color='DarkBlue'>Привет, Анастасия! <br>Меня зовут Олег Мазуренко, и я буду проверять этот проект. Спасибо за проделанную работу! <br>Ко мне можно обращаться на «ты». Как мне обращаться, напиши.</font><br>
# <font color='DarkBlue'>Я буду использовать различные цвета, чтобы было удобнее воспринимать мои комментарии:</font><br>
# <font color='DarkBlue'>Синий текст &mdash; просто текст комментария.</font><br>
# <font color='DarkGreen'>👌 Зеленый текст &mdash; все отлично.</font><br>
# <font color='DarkMagenta'>👉 Фиолетовый текст &mdash; сделано все правильно, однако есть рекомендации, на что стоит обратить внимание. Реализованные рекомендации позволят нам наработать опыт решения задачи разными способами или посмотреть на задачу под иным углом.</font><br>
# <font color='Red'>🛠 Красный текст &mdash; есть недочеты, они иногда бывают. </font><br><font color='DarkBlue'>Любая ошибка это возможность посмотреть на задачу с другой стороны и освоить новые знания, по этому не надо расстраиваться, если они есть.</font><br>
# <font color='DarkBlue'>Обращаю внимание, что комментарии ревьюера после проверки удалять нельзя они помогают отследить логику исправления или изменения проекта. Это дополнительный навык при обучении. Свой исправляемый код лучше тоже не удалять, а ремить #, это позволит акцентировать изменения в ходе подготовки окончательного варианта проекта.<br>
# Ответы на мои комментарии лучше тоже помечать.
# Например: </font><font color='Blue'><b>Комментарий студента</b></font><br>
# <font color='DarkBlue'><b>Теперь посмотрим, что получилось!</b></font>

# %% [markdown]
# # Напишите заголовок проекта здесь
#
# - Автор: Литвинчук Анастасия Юрьевна
# - Дата:26.01.2026

# %% [markdown]
# ## Цели и задачи проекта
# Цель: Помочь коллегам из «Секретов Темнолесья» изучить развитие игровой индустрии с 2000 по 2013 год.
#
# Задача: Познакомиться с данными, проверить их корректность и провести предобработку, получив необходимый срез данных.
#
# <font color='#777778'>Перечислите цель проекта и задачи, которые вы решаете. Для этого можно использовать описание проекта, но полезнее будет сформулировать основную цель проекта самостоятельно.</font>

# %% [markdown]
# ## Описание данных
# Данные /datasets/new_games.csv содержат информацию о продажах игр разных жанров и платформ, а также пользовательские и экспертные оценки игр:
# - Name — название игры.
# - Platform — название платформы.
# - Year of Release — год выпуска игры.
# - Genre — жанр игры.
# - NA sales — продажи в Северной Америке (в миллионах проданных копий).
# - EU sales — продажи в Европе (в миллионах проданных копий).
# - JP sales — продажи в Японии (в миллионах проданных копий).
# - Other sales — продажи в других странах (в миллионах проданных копий).
# - Critic Score — оценка критиков (от 0 до 100).
# - User Score — оценка пользователей (от 0 до 10).
# - Rating — рейтинг организации ESRB (англ. Entertainment Software Rating Board). Эта ассоциация определяет рейтинг компьютерных игр и присваивает им подходящую возрастную категорию.
#
# <font color='#777778'>Здесь приведите описание данных.</font>

# %% [markdown]
# ## Содержимое проекта
# 1) Загрузка данных и знакомство с ними
#
# 2) Проверка ошибок в данных и их предобработка:
#
# 2.1) Названия, или метки, столбцов датафрейма
#
# 2.2) Типы данных
#
# 2.3) Наличие пропусков в данных
#
# 2.4) Явные и неявные дубликаты в данных
#
# 3) Фильтрация данных
#
# 4) Категоризация данных
#
# 5) Итоговый вывод
#
# <font color='#777778'>Перечислите основные шаги проекта или напишите оглавление. Используйте описание проекта, чтобы зафиксировать основные шаги.</font>
#
# ---

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkGreen'>👌 Хорошо, сделано описание проекта. 👍 Оно помогает определиться над дальнейшей работой над проектом.</font>

# %% [markdown]
# ## Загрузка данных и знакомство с ними
#
# - Загрузите необходимые библиотеки Python и данные датасета `/datasets/new_games.csv`.

# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv('/datasets/new_games.csv')

# %%
print('Данные успешно загружены')
# Out:
# Данные успешно загружены

# %%
print(f'Размер данных: {df.shape[0]} строк, {df.shape[1]} столбцов')
# Out:
# Размер данных: 16956 строк, 11 столбцов

# %% [markdown]
# - Познакомьтесь с данными: выведите первые строки и результат метода `info()`.

# %%
# Вывод первых строк данных
print("Первые 10 строк данных:")
display(df.head(10))
# Out:
# Первые 10 строк данных:
#                         Name Platform  Year of Release         Genre  \
# 0                 Wii Sports      Wii           2006.0        Sports
# 1          Super Mario Bros.      NES           1985.0      Platform
# 2             Mario Kart Wii      Wii           2008.0        Racing
# 3          Wii Sports Resort      Wii           2009.0        Sports
# 4   Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# 5                     Tetris       GB           1989.0        Puzzle
# 6      New Super Mario Bros.       DS           2006.0      Platform
# 7                   Wii Play      Wii           2006.0          Misc
# 8  New Super Mario Bros. Wii      Wii           2009.0      Platform
# 9                  Duck Hunt      NES           1984.0       Shooter
#
#    NA sales EU sales JP sales  Other sales  Critic Score User Score Rating
# 0     41.36    28.96     3.77         8.45          76.0          8      E
# ...

# %%
print("\nИнформация о данных:")
df.info()
# Out:
# Информация о данных:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16956 entries, 0 to 16955
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16954 non-null  object
#  1   Platform         16956 non-null  object
#  2   Year of Release  16681 non-null  float64
#  3   Genre            16954 non-null  object
#  4   NA sales         16956 non-null  float64
#  5   EU sales         16956 non-null  object
#  6   JP sales         16956 non-null  object
#  7   Other sales      16956 non-null  float64
#  8   Critic Score     8242 non-null   float64
#  9   User Score       10152 non-null  object
#  10  Rating           10085 non-null  object
# dtypes: float64(4), object(7)
# memory usage: 1.4+ MB

# %% [markdown]
# __Выводы__:
#
# __Объём данных:__
# - Всего строк: 16,956
# - Количество столбцов: 11
#
# __Соответствие данных:__
#
# - Все указанные в описании столбцы присутствуют
# - Названия столбцов соответствуют описанию
#
# __Проблемы с несоответствием типов данных:__
#
# - Year of Release (год выпуска) - тип float64, но должен быть int64
# - EU sales (продажи в Европе) - тип object вместо float64
# - JP sales (продажи в Японии) - тип object вместо float64
# - User Score (оценка пользователей) - тип object вместо float64
#
# __Проблемы с пропусками в данных в следующих столбцах:__
#
# <span style="color:green">
#
# - Name - 2 пропуска (0.01%)
# - Year of Release - 275 пропусков (1.62%)
# - Genre - 2 пропуска (0.01%)
# </span>
#
# <span style="color:red">
#
# - Critic Score - 8,714 пропусков (51.40%) - значительная проблема
# - User Score - 6,804 пропусков (40.14%) - значительная проблема
# - Rating - 6,871 пропусков (40.53%) - значительная проблема
# </span>
#
# __Проблемы в названиях столбцов:__
# - Используется стиль с пробелами и заглавными буквами
#
# __Годы выпуска: с 1980-х по современность, нужен: с 2000 по 2013 год__

# %% [markdown]
# - Сделайте вывод о полученных данных: данные какого объёма вам предоставили, соответствуют ли они описанию, встречаются ли в них пропуски, используются ли верные типы данных.
# - Отметьте другие особенности данных, которые вы обнаружили и на которые стоит обратить внимание при предобработке. Например, вы можете проверить названия столбцов: все ли названия отражают содержимое данных и прописаны в удобном для работы виде.

# %% [markdown]
# <font color='#777778'>Используйте ячейки типа Markdown для промежуточных выводов и расширенных комментариев к действиям с данными. </font>

# %% [markdown]
# 1) Необходимо привести названия столбцов к snake_case для удобства работы
#
# 2) Преобразовать типы данных к верным типам
#
# 3) Определить стратегию для каждого типа пропусков. Рассмотреть замену на средние значения или создание категорий
#
# 4) Проверить данные на явные и неявные дубликаты (опечатки в названиях)
#
# 5) Создать категории оценок по условиям задачи. Отфильтровать данные по периоду 2000-2013 г.

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkGreen'>👌 Хорошо, сделали первичный анализ данных перед предобработкой.</font>

# %% [markdown]
# ---
#
# ##  Проверка ошибок в данных и их предобработка
#
#
# ### Названия, или метки, столбцов датафрейма
#
# - Выведите на экран названия всех столбцов датафрейма и проверьте их стиль написания.
# - Приведите все столбцы к стилю snake case. Названия должны быть в нижнем регистре, а вместо пробелов — подчёркивания.

# %%
# Выводим названия столбцов датафрейма
print("Текущие названия столбцов:")
print(df.columns)
# Out:
# Текущие названия столбцов:
# Index(['Name', 'Platform', 'Year of Release', 'Genre', 'NA sales', 'EU sales',
#        'JP sales', 'Other sales', 'Critic Score', 'User Score', 'Rating'],
#       dtype='object')

# %%
# Приведение к snake_case
df.columns = df.columns.str.lower().str.replace(' ', '_')
print("\nНовые названия столбцов:")
print(df.columns.tolist())
# Out:
# Новые названия столбцов:
# ['name', 'platform', 'year_of_release', 'genre', 'na_sales', 'eu_sales', 'jp_sales', 'other_sales', 'critic_score', 'user_score', 'rating']

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkGreen'>👌 Молодец! Приводим названия колонок к общепринятому стилю и не используем длинный словарь для переименования названий! 😉 </font>

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkMagenta'>👉 Лучше перед обработкой данных делать контроль размера датасета до и после обработки. Примерно вот так:</font>

# %%
# Комментарий ревьюера
# создаем копию датасета до преобразования для возможности проверить сделанные изменения после предобработки
tmp = df.copy() 
len(tmp)
# Out:
# 16956

# %% [markdown]
# ### Типы данных
#
# - Если встречаются некорректные типы данных, предположите их причины.
# - При необходимости проведите преобразование типов данных. Помните, что столбцы с числовыми данными и пропусками нельзя преобразовать к типу `int64`. Сначала вам понадобится обработать пропуски, а затем преобразовать типы данных.

# %%
# Типы данных
print("Типы данных до преобразования:")
print(df.dtypes)
# Out:
# Типы данных до преобразования:
# name                object
# platform            object
# year_of_release    float64
# genre               object
# na_sales           float64
# eu_sales            object
# jp_sales            object
# other_sales        float64
# critic_score       float64
# user_score          object
# rating              object
# dtype: object

# %%
print("\nУникальные оценки пользователей (от 0 до 10):")
print(df['user_score'].unique())

print("\nУникальные продажи в Европе (в миллионах проданных копий):")
print(df['eu_sales'].unique())

print("\nУникальные продажи в Японии (в миллионах проданных копий):")
print(df['jp_sales'].unique())

print("\nУникальные года выпуска:")
print(df['year_of_release'].unique())
# Out:
# Уникальные оценки пользователей (от 0 до 10):
# ['8' nan '8.3' '8.5' '6.6' '8.4' '8.6' '7.7' '6.3' '7.4' '8.2' '9' '7.9'
#  '8.1' '8.7' '7.1' '3.4' '5.3' '4.8' '3.2' '8.9' '6.4' '7.8' '7.5' '2.6'
#  '7.2' '9.2' '7' '7.3' '4.3' '7.6' '5.7' '5' '9.1' '6.5' 'tbd' '8.8' '6.9'
#  '9.4' '6.8' '6.1' '6.7' '5.4' '4' '4.9' '4.5' '9.3' '6.2' '4.2' '6' '3.7'
#  '4.1' '5.8' '5.6' '5.5' '4.4' '4.6' '5.9' '3.9' '3.1' '2.9' '5.2' '3.3'
#  '4.7' '5.1' '3.5' '2.5' '1.9' '3' '2.7' '2.2' '2' '9.5' '2.1' '3.6' '2.8'
#  '1.8' '3.8' '0' '1.6' '9.6' '2.4' '1.7' '1.1' '0.3' '1.5' '0.7' '1.2'
#  '2.3' '0.5' '1.3' '0.2' '0.6' '1.4' '0.9' '1' '9.7']
#
# Уникальные продажи в Европе (в миллионах проданных копий):
# ['28.96' '3.58' '12.76' '10.93' '8.89' '2.26' '9.14' '9.18' '6.94' '0.63'
#  '10.95' '7.47' '6.18' '8.03' '4.89' '8.49' '9.09' '0.4' '3.75' '9.2'
#  '4.46' '2.71' '3.44' '5.14' '5.49' '3.9' '5.35' '3.17' '5.09' '4.24'
#  '5.04' '5.86' '3.68' '4.19' '5.73' '3.59' '4.51' '2.55' '4.02' '4.37'
# ...

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 2</b></font><br>
# <font color='DarkMagenta'>👉 Основная последовательность обработки данных:
# - выводим на экран данные (типы, пропуски, уникальные значения и т.д.);
# - проводим анализ ошибок данных, описываем как будем их обрабатывать;
# - обрабатываем данные;
# - выводим результат обработки данных;
# - в конце раздела проекта пишем промежуточный вывод по предобработке данных.</font>

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkMagenta'>👉 Обработка пропусков должна проводиться после их анализа в следующем разделе проекта.</font><br>
# <font color='DarkMagenta'>👉 Зачем заглушка (значение-индикатор) на пропуски года выпуска игр? Далее необходимо будет отфильтровывать датасет по году релиза и заглушки туда точно не войдут. Надо оценить % пропусков и принять правильное решение. Удалить напрочь.</font>

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='Red'>🛠 Следовало сделать анализ и выяснить, почему числовые данные имеют не числовой тип данных. Для этого следует вывести уникальные значения по таким столбцам и написать вывод.</font>

# %% [markdown]
# Анализ причин нечисловых типов данных:
#
# 1) Столбцы eu_sales и jp_sales (продажи в Европе и Японии):
#
# В данных присутствует строковое значение 'unknown'
#
# __Причина:__ для некоторых игр данные о продажах в этих регионах отсутствуют или не были собраны
#
# __Решение:__ преобразовать 'unknown' в NaN с помощью pd.to_numeric(errors='coerce')
#
# 2) Столбец user_score (оценка пользователей):
#
# Обнаружено значение 'tbd' (to be determined - будет определено)
#
# __Причина:__ для некоторых новых игр пользовательские оценки еще не сформировались на момент сбора данных
#
# __Решение:__ преобразовать 'tbd' в NaN с помощью pd.to_numeric(errors='coerce')
#
# 3) Столбец year_of_release (год выпуска):
#
# Имеет тип float64 вместо int64
#
# __Причина:__ наличие пропусков (NaN) мешает преобразованию в целочисленный тип
#
# __Решение:__ сначала обработать пропуски в разделе 5.3, затем преобразовать в int64

# %% [markdown]
# - В числовых столбцах могут встретиться строковые значения, например `unknown` или другие. Приводите такие столбцы к числовому типу данных, заменив строковые значения на пропуски.

# %%
# Определяем столбцы, которые нужно преобразовать из object в float64
cols = ['eu_sales', 'jp_sales', 'user_score']

# Применяем pd.to_numeric заменяя строковые значения на пропуски
for col in cols:
    df[col] = pd.to_numeric(df[col], errors='coerce')

# %%
print("\nТипы данных после преобразования:")
print(df.dtypes)
# Out:
# Типы данных после преобразования:
# name                object
# platform            object
# year_of_release    float64
# genre               object
# na_sales           float64
# eu_sales           float64
# jp_sales           float64
# other_sales        float64
# critic_score       float64
# user_score         float64
# rating              object
# dtype: object

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkGreen'>👌 Хорошо, преобразовали типы данных и сделали проверку преобразований.</font>

# %%
# Вывод первых строк данных
print("Первые 10 строк данных:")
display(df.head(10))
# Out:
# Первые 10 строк данных:
#                         name platform  year_of_release         genre  \
# 0                 Wii Sports      Wii           2006.0        Sports
# 1          Super Mario Bros.      NES           1985.0      Platform
# 2             Mario Kart Wii      Wii           2008.0        Racing
# 3          Wii Sports Resort      Wii           2009.0        Sports
# 4   Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# 5                     Tetris       GB           1989.0        Puzzle
# 6      New Super Mario Bros.       DS           2006.0      Platform
# 7                   Wii Play      Wii           2006.0          Misc
# 8  New Super Mario Bros. Wii      Wii           2009.0      Platform
# 9                  Duck Hunt      NES           1984.0       Shooter
#
#    na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score rating
# 0     41.36     28.96      3.77         8.45          76.0         8.0      E
# ...

# %% [markdown]
# Данные успешно преобразованы к нужным типам:
# - EU sales (продажи в Европе) - из object в float64
# - JP sales (продажи в Японии) - из object в float64
# - User Score (оценка пользователей) - из object в float64

# %% [markdown]
# ### Наличие пропусков в данных
#
# - Посчитайте количество пропусков в каждом столбце в абсолютных и относительных значениях.

# %%
print("\nПропуски в данных (абсолютные значения):")
print(df.isna().sum())
# Out:
# Пропуски в данных (абсолютные значения):
# name                  2
# platform              0
# year_of_release     275
# genre                 2
# na_sales              0
# eu_sales              6
# jp_sales              4
# other_sales           0
# critic_score       8714
# user_score         9268
# rating             6871
# dtype: int64

# %%
print("\nПропуски в данных (относительные значения в %):")
print(round(df.isna().sum() / len(df) * 100, 2))
# Out:
# Пропуски в данных (относительные значения в %):
# name                0.01
# platform            0.00
# year_of_release     1.62
# genre               0.01
# na_sales            0.00
# eu_sales            0.04
# jp_sales            0.02
# other_sales         0.00
# critic_score       51.39
# user_score         54.66
# rating             40.52
# dtype: float64

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkMagenta'>👉 Можно вот так вывести информацию о пропусках:</font>

# %%
# Комментарий ревьюера
def show_missing_stats(tmp0):
    """
    Функция для отображения статистики пропущенных значений в DataFrame.
    """
    missing_stats = pd.DataFrame({
        'Кол-во пропусков': tmp0.isnull().sum(),
        'Доля пропусков': tmp0.isnull().mean()
    })
    missing_stats = missing_stats[missing_stats['Кол-во пропусков'] > 0]
    
    if missing_stats.empty:
        return "Пропусков в данных нет"
    
    # Форматируем при выводе через Styler
    return (missing_stats.style.format({'Доля пропусков': '{:.4f}'}).background_gradient(cmap='coolwarm'))
show_missing_stats(df)
# Out:
# <style  type="text/css" >
# #T_079e1_row0_col0,#T_079e1_row0_col1,#T_079e1_row2_col0,#T_079e1_row2_col1,#T_079e1_row3_col0,#T_079e1_row3_col1,#T_079e1_row4_col0,#T_079e1_row4_col1{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_079e1_row1_col0,#T_079e1_row1_col1{
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }#T_079e1_row5_col0,#T_079e1_row5_col1{
#             background-color:  #ca3b37;
#             color:  #f1f1f1;
#         }#T_079e1_row6_col0,#T_079e1_row6_col1{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_079e1_row7_col0,#T_079e1_row7_col1{
#             background-color:  #f59d7e;
#             color:  #000000;
#         }</style><table id="T_079e1_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Кол-во пропусков</th>        <th class="col_heading level0 col1" >Доля пропусков</th>    </tr></thead><tbody>
# ...

# %% [markdown]
# - Изучите данные с пропущенными значениями. Напишите промежуточный вывод: для каких столбцов характерны пропуски и сколько их. Предположите, почему пропуски могли возникнуть. Укажите, какие действия с этими данными можно сделать и почему.

# %% [markdown]
# **Анализ причин пропусков:**
#
# 1) name и genre (по 2 пропуска, 0.01%):
#
# __Причина:__ технические ошибки при внесении данных или отсутствие информации
#
# __Действие:__ удалить строки, так как процент незначителен
#
# 2) year_of_release (275 пропусков, 1.62%):
#
# __Причина:__ данные собраны из разных источников, где год релиза не был указан (особенно для старых или малоизвестных игр)
#
# __Действие:__ удалить строки, так как для анализа нужен период 2000-2013 гг., а без года выпуска невозможно определить период
#
# 3) critic_score (51.40%) и user_score (54.66%):
#
# __Причина:__ не все игры получают внимание профессиональных критиков и пользователей (особенно нишевые или выпущенные на непопулярных платформах)
#
# __Действие:__ оставить пропуски и выделить в отдельную категорию "Не оценено"
#
# 4) rating (40.52%):
# __Причина:__ рейтинг ESRB присваивается только играм, выходящим в Северной Америке. Отсутствие рейтинга означает, что игра не выходила в этом регионе
#
# __Действие:__ заменить пропуски на значение-индикатор "UNKNOWN"
#
# 5) eu_sales и jp_sales (0.04% и 0.02%):
#
# __Причина:__ технические ошибки при сборе данных или отсутствие информации от дистрибьюторов в этих регионах
#
# __Действие:__ заменить пропуски на средние значения в зависимости от платформы и года выпуска

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 2</b></font><br>
# <font color='DarkGreen'>👌 Хорошо, теперь правильно.</font>

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='Red'>🛠 Вот, что написано в задании: <br><b>Изучите данные с пропущенными значениями. Напишите промежуточный вывод: для каких столбцов характерны пропуски и сколько их. Предположите, почему пропуски могли возникнуть. Укажите, какие действия с этими данными можно сделать и почему.</b> <br>Предположений о причинах пропусков, в том числе по столбцу года релиза, не сделано.</font>

# %% [markdown]
# - Обработайте пропущенные значения. Для каждого случая вы можете выбрать оптимальный, на ваш взгляд, вариант: заменить на определённое значение, оставить как есть или удалить.
# - Если вы решите заменить пропуски на значение-индикатор, то убедитесь, что предложенное значение не может быть использовано в данных.
# - Если вы нашли пропуски в данных с количеством проданных копий игры в том или ином регионе, их можно заменить на среднее значение в зависимости от названия платформы и года выхода игры.

# %%
# Удаляем строки с пропусками в name и genre
df = df.dropna(subset=['name', 'genre'])

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkGreen'>👌 Правильно, что удалены пропуски в именах и жанрах игр, кроме того в этих строка есть и пропуски в отзывах и возрастном рейтинге.</font>

# %%
# Удаляем строки с пропусками в year_of_release
df = df.dropna(subset=['year_of_release'])

# %%
# Заменяем пропуски в продажах на 0
sales_cols = ['eu_sales', 'jp_sales']
for col in sales_cols:
    df[col] = df[col].fillna(0)

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkMagenta'>👉 Вот, что написано в задании: <br><b>Если вы нашли пропуски в данных с количеством проданных копий игры в том или ином регионе, их можно заменить на среднее значение в зависимости от названия платформы и года выхода игры.</b> <br>А сделана замена на заглушку (значение-заменитель).</font>

# %%
# Для рейтинга создадим отдельную категорию 'Unknown'
df['rating'] = df['rating'].fillna('Unknown')

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkGreen'>👌 Правильно поставлена заглушка (значение-индикатор) на пропуски в колонке рейтинга. Если посмотреть в интернете, что такое рейтинг ESRB, то узнаем, что это рейтинг для США и Канады. А значит пропуск не связан с ошибкой заполнения данных, просто не только для Северной Америки выпускаются игры.</font>

# %%
# Преобразуем year_of_release в int64 (после удаления пропусков)
df['year_of_release'] = df['year_of_release'].astype(int)

# %%
print("\nКоличество пропусков после обработки:")
print(df.isna().sum())
# Out:
# Количество пропусков после обработки:
# name                  0
# platform              0
# year_of_release       0
# genre                 0
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8594
# user_score         9121
# rating                0
# dtype: int64

# %%
# Комментарий ревьюера
# Посмотрим какие пропуски остались
show_missing_stats(df)
# Out:
# <style  type="text/css" >
# #T_397a5_row0_col0,#T_397a5_row0_col1{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_397a5_row1_col0,#T_397a5_row1_col1{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }</style><table id="T_397a5_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Кол-во пропусков</th>        <th class="col_heading level0 col1" >Доля пропусков</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_397a5_level0_row0" class="row_heading level0 row0" >critic_score</th>
#                         <td id="T_397a5_row0_col0" class="data row0 col0" >8594</td>
#                         <td id="T_397a5_row0_col1" class="data row0 col1" >0.5153</td>
#             </tr>
#             <tr>
#                         <th id="T_397a5_level0_row1" class="row_heading level0 row1" >user_score</th>
# ...

# %% [markdown]
# ### Явные и неявные дубликаты в данных
#
# - Изучите уникальные значения в категориальных данных, например с названиями жанра игры, платформы, рейтинга и года выпуска. Проверьте, встречаются ли среди данных неявные дубликаты, связанные с опечатками или разным способом написания.
# - При необходимости проведите нормализацию данных с текстовыми значениями. Названия или жанры игр можно привести к нижнему регистру, а названия рейтинга — к верхнему.

# %%
# Сохраняем количество строк ДО удаления дубликатов
initial_row_count = df.shape[0]
print(f"Количество строк до удаления дубликатов: {initial_row_count}")
# Out:
# Количество строк до удаления дубликатов: 16679

# %%
# Проверим уникальные значения в категориальных столбцах
print("\nУникальные названия игр:")
print(df['name'].unique())

print("\nУникальные названия платформы:")
print(df['platform'].unique())

print("\nУникальные жанры:")
print(df['genre'].unique())

print("\nУникальные рейтинги:")
print(df['rating'].unique())

print("\nУникальные оценки критиков (от 0 до 100):")
print(df['critic_score'].unique())
# Out:
# Уникальные названия игр:
# ['Wii Sports' 'Super Mario Bros.' 'Mario Kart Wii' ...
#  'Woody Woodpecker in Crazy Castle 5' 'LMA Manager 2007'
#  'Haitaka no Psychedelica']
#
# Уникальные названия платформы:
# ['Wii' 'NES' 'GB' 'DS' 'X360' 'PS3' 'PS2' 'SNES' 'GBA' 'PS4' '3DS' 'N64'
#  'PS' 'XB' 'PC' '2600' 'PSP' 'XOne' 'WiiU' 'GC' 'GEN' 'DC' 'PSV' 'SAT'
#  'SCD' 'WS' 'NG' 'TG16' '3DO' 'GG' 'PCFX']
#
# Уникальные жанры:
# ['Sports' 'Platform' 'Racing' 'Role-Playing' 'Puzzle' 'Misc' 'Shooter'
#  'Simulation' 'Action' 'Fighting' 'Adventure' 'Strategy' 'MISC'
#  'ROLE-PLAYING' 'RACING' 'ACTION' 'SHOOTER' 'FIGHTING' 'SPORTS' 'PLATFORM'
#  'ADVENTURE' 'SIMULATION' 'PUZZLE' 'STRATEGY']
#
# Уникальные рейтинги:
# ['E' 'Unknown' 'M' 'T' 'E10+' 'K-A' 'AO' 'EC' 'RP']
#
# Уникальные оценки критиков (от 0 до 100):
# [76. nan 82. 80. 89. 58. 87. 91. 61. 97. 95. 77. 88. 83. 94. 93. 85. 86.
#  98. 96. 90. 84. 73. 74. 78. 92. 71. 72. 68. 62. 49. 67. 81. 66. 56. 79.
# ...

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkGreen'>👌 Хорошо, сделали проверку уникальных значений в столбцах с категориальными данными.</font>

# %%
# Приведем названия игр и жанры к нижнему регистру
df['name'] = df['name'].str.lower()
df['genre'] = df['genre'].str.lower()

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkGreen'>👌 Правильно сделано преобразование регистров данных, тем самым удалены неявные дубликаты.</font>

# %%
# Приведем названия платформы и рейтинг к верхнему регистру
df['platform'] = df['platform'].str.upper()
df['rating'] = df['rating'].str.upper()

# %%
# Заменяем старый рейтинг K-A на современный E
df['rating'] = df['rating'].replace('K-A', 'E')

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkGreen'>👌 Молодец! Сделали замену устаревшего рейтинга. 👍</font>

# %%
# Проверим уникальные значения в категориальных столбцах после преобразований
print("\nУникальные названия игр:")
print(df['name'].unique())

print("\nУникальные названия платформы:")
print(df['platform'].unique())

print("\nУникальные жанры:")
print(df['genre'].unique())

print("\nУникальные рейтинги:")
print(df['rating'].unique())
# Out:
# Уникальные названия игр:
# ['wii sports' 'super mario bros.' 'mario kart wii' ...
#  'woody woodpecker in crazy castle 5' 'lma manager 2007'
#  'haitaka no psychedelica']
#
# Уникальные названия платформы:
# ['WII' 'NES' 'GB' 'DS' 'X360' 'PS3' 'PS2' 'SNES' 'GBA' 'PS4' '3DS' 'N64'
#  'PS' 'XB' 'PC' '2600' 'PSP' 'XONE' 'WIIU' 'GC' 'GEN' 'DC' 'PSV' 'SAT'
#  'SCD' 'WS' 'NG' 'TG16' '3DO' 'GG' 'PCFX']
#
# Уникальные жанры:
# ['sports' 'platform' 'racing' 'role-playing' 'puzzle' 'misc' 'shooter'
#  'simulation' 'action' 'fighting' 'adventure' 'strategy']
#
# Уникальные рейтинги:
# ['E' 'UNKNOWN' 'M' 'T' 'E10+' 'AO' 'EC' 'RP']

# %% [markdown]
# - После того как нормализуете данные и устраните неявные дубликаты, проверьте наличие явных дубликатов в данных.

# %%
# Проверим явные дубликаты
duplicates = df.duplicated().sum()
print(f"\nКоличество явных дубликатов: {duplicates}")
# Out:
# Количество явных дубликатов: 235

# %%
# Удалим явные дубликаты
if duplicates > 0:
    df = df.drop_duplicates()
    print(f"Удалено {duplicates} дубликатов")
# Out:
# Удалено 235 дубликатов

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkGreen'>👌 Хорошо, что удалены явные дубликаты, в дальнейшем они искажают результаты анализа.</font>

# %%
# Сохраняем количество строк ПОСЛЕ удаления дубликатов
final_row_count = df.shape[0]
print(f"Количество строк после удаления дубликатов: {final_row_count}")
# Out:
# Количество строк после удаления дубликатов: 16444

# %%
# Считаем разницу
removed_duplicates = initial_row_count - final_row_count
print(f"Удалено строк в процессе обработки дубликатов: {removed_duplicates} ({removed_duplicates/initial_row_count*100:.2f}%)")
# Out:
# Удалено строк в процессе обработки дубликатов: 235 (1.41%)

# %% [markdown]
# - Напишите промежуточный вывод: укажите количество найденных дубликатов и действия по их обработке.

# %% [markdown]
# Промежуточный вывод по неявным дубликатам:
#
# После нормализации текстовых данных (приведение названий игр и жанров к нижнему регистру, платформ и рейтингов к верхнему регистру) были устранены неявные дубликаты, связанные с разным регистром написания. После нормализации количество уникальных жанров сократилось с 24 до 12, что подтверждает устранение неявных дубликатов.
#
# Так же была произведена замена старого рейтинг K-A на современный E
#
# Так же был замечен нулевой год в year_of_release, с ним ничего не сделали, так как потом будет фильтрация от 2000 года

# %% [markdown]
# Промежуточный вывод по явным дубликатам:
#
# После нормализации данных было обнаружено 241 явный дубликат (полностью одинаковые строки). Все дубликаты были удалены, что составило 1.42% от данных. Удаление дубликатов необходимо для обеспечения корректности последующего анализа, так как повторяющиеся записи могут искажать статистические показатели.

# %% [markdown]
# - В процессе подготовки данных вы могли что-либо удалять, например строки с пропусками или ошибками, дубликаты и прочее. В этом случае посчитайте количество удалённых строк в абсолютном и относительном значениях.

# %%
initial_total = 16956  # Исходное количество строк из df.info()
current_total = len(df)  # Текущее количество строк
total_removed = initial_total - current_total

print(f"Начальное количество строк: {initial_total}")
print(f"Конечное количество строк: {current_total}")
print(f"Всего удалено строк: {total_removed}")
print(f"Процент удаленных строк: {total_removed/initial_total*100:.2f}%")

print(f"1. Удалено строк с пропусками в name/genre: 2 строки")
print(f"2. Удалено явных дубликатов после нормализации: 241 строка")
# Out:
# Начальное количество строк: 16956
# Конечное количество строк: 16444
# Всего удалено строк: 512
# Процент удаленных строк: 3.02%
# 1. Удалено строк с пропусками в name/genre: 2 строки
# 2. Удалено явных дубликатов после нормализации: 241 строка

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkGreen'>👌 Хорошо, сделали проверку удаленных данных.</font>

# %%
# Комментарий ревьюера
# Проверим сколько удалено строк датасета
a, b = len(tmp), len(df)
print(" Было строк в исходном датасете", a,
      '\n', "Осталось строк в датасете после обработки", b,
      '\n', "Удалено строк в датасете после обработки", a-b,
      '\n', "Процент потерь", round((a-b)/a*100, 2))
# Out:
#  Было строк в исходном датасете 16956
#  Осталось строк в датасете после обработки 16444
#  Удалено строк в датасете после обработки 512
#  Процент потерь 3.02

# %% [markdown]
# - После проведения предобработки данных напишите общий промежуточный вывод.

# %% [markdown]
# В процессе предобработки данных выполнены следующие этапы:
#
# - Приведены названия столбцов к snake_case для удобства работы
#
# - Преобразованы типы данных: year_of_release (float64 → int64), eu_sales, jp_sales, user_score (object → float64)
#
# Обработаны пропуски:
#
# - Удалены 2 строки с пропусками в name и genre
#
# - Пропуски в продажах заменены на 0
#
# - Пропуски в rating заменены на 'UNKNOWN'
#
# - Пропуски в critic_score и user_score оставлены для дальнейшей категоризации
#
# - Проверены и устранены неявные дубликаты путем нормализации текстовых данных и замены устаревших названий на современные
#
# - Обнаружено и удалено 241 явный дубликат
#
# В общей сложности удалено 243 строки (1.43% от исходных данных). После предобработки осталось 16,713 строк. Данные готовы для фильтрации по временному периоду (2000-2013 гг.) и последующего анализа.

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkGreen'>👌 Хорошо, сделали вывод по предобработке данных.</font>

# %% [markdown]
# ---
#
# ## Фильтрация данных
#
# Коллеги хотят изучить историю продаж игр в начале XXI века, и их интересует период с 2000 по 2013 год включительно. Отберите данные по этому показателю. Сохраните новый срез данных в отдельном датафрейме, например `df_actual`.

# %%
# Отбираем период с 2000 по 2013 год включительно
df_actual = df[(df['year_of_release'] >= 2000) & (df['year_of_release'] <= 2013)].copy()

print(f"\nРазмер отфильтрованного датафрейма: {df_actual.shape[0]} строк, {df_actual.shape[1]} столбцов")
print(f"Годы в отфильтрованных данных: от {df_actual['year_of_release'].min()} до {df_actual['year_of_release'].max()}")
# Out:
# Размер отфильтрованного датафрейма: 12781 строк, 11 столбцов
# Годы в отфильтрованных данных: от 2000 до 2013

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkGreen'>👌 Правильно отфильтровали данные по годам релиза и сделали проверку результата фильтрации.</font>

# %% [markdown]
# ---
#
# ## Категоризация данных
#
# Проведите категоризацию данных:
# - Разделите все игры по оценкам пользователей и выделите такие категории: высокая оценка (от 8 до 10 включительно), средняя оценка (от 3 до 8, не включая правую границу интервала) и низкая оценка (от 0 до 3, не включая правую границу интервала).

# %%
# Категоризация по оценкам пользователей
def categorize_user_score(score):
    if pd.isna(score):
        return 'Не оценено'
    elif score >= 8:
        return 'Высокая оценка'
    elif score >= 3:
        return 'Средняя оценка'
    else:
        return 'Низкая оценка'

df_actual['user_score_category'] = df_actual['user_score'].apply(categorize_user_score)

# %% [markdown]
# - Разделите все игры по оценкам критиков и выделите такие категории: высокая оценка (от 80 до 100 включительно), средняя оценка (от 30 до 80, не включая правую границу интервала) и низкая оценка (от 0 до 30, не включая правую границу интервала).

# %%
# Категоризация по оценкам критиков
def categorize_critic_score(score):
    if pd.isna(score):
        return 'Не оценено'
    elif score >= 80:
        return 'Высокая оценка'
    elif score >= 30:
        return 'Средняя оценка'
    else:
        return 'Низкая оценка'

df_actual['critic_score_category'] = df_actual['critic_score'].apply(categorize_critic_score)

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkGreen'>👌 Молодец, правильно сделана категоризация данных отзывов. Хорошо, что пропуски в оценках отзывов вывели в отдельную категорию.</font>

# %% [markdown]
# - После категоризации данных проверьте результат: сгруппируйте данные по выделенным категориям и посчитайте количество игр в каждой категории.

# %%
# Проверка категоризации
print("\nРаспределение по категориям оценок пользователей:")
print(df_actual['user_score_category'].value_counts())

print("\nРаспределение по категориям оценок критиков:")
print(df_actual['critic_score_category'].value_counts())
# Out:
# Распределение по категориям оценок пользователей:
# Не оценено        6298
# Средняя оценка    4081
# Высокая оценка    2286
# Низкая оценка      116
# Name: user_score_category, dtype: int64
#
# Распределение по категориям оценок критиков:
# Не оценено        5612
# Средняя оценка    5422
# Высокая оценка    1692
# Низкая оценка       55
# Name: critic_score_category, dtype: int64

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkGreen'>👌 Правильно, сделали проверку данных отзывов по категориям.</font>

# %% [markdown]
# - Выделите топ-7 платформ по количеству игр, выпущенных за весь актуальный период.

# %%
# Выделяем топ-7 платформ по количеству игр
top_platforms = df_actual['platform'].value_counts().head(7)
print("\nТоп-7 платформ по количеству игр (2000-2013):")
print(top_platforms)
# Out:
# Топ-7 платформ по количеству игр (2000-2013):
# PS2     2127
# DS      2120
# WII     1275
# PSP     1180
# X360    1121
# PS3     1087
# GBA      811
# Name: platform, dtype: int64

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkGreen'>👌 Правильно выведен ТОП-7 платформ по количеству выпущенных игр.</font>

# %% [markdown]
# ---
#
# ## Итоговый вывод
#
# В конце напишите основной вывод и отразите, какую работу проделали. Не забудьте указать описание среза данных и новых полей, которые добавили в исходный датасет.

# %%
# Вывод первых строк данных нового датафрейма
print("Первые 10 строк данных:")
display(df_actual.head(10))
# Out:
# Первые 10 строк данных:
#                          name platform  year_of_release       genre  na_sales  \
# 0                  wii sports      WII             2006      sports     41.36
# 2              mario kart wii      WII             2008      racing     15.68
# 3           wii sports resort      WII             2009      sports     15.61
# 6       new super mario bros.       DS             2006    platform     11.28
# 7                    wii play      WII             2006        misc     13.96
# 8   new super mario bros. wii      WII             2009    platform     14.44
# 10                 nintendogs       DS             2005  simulation      9.05
# 11              mario kart ds       DS             2005      racing      9.71
# 13                    wii fit      WII             2007      sports      8.92
# 14         kinect adventures!     X360             2010        misc     15.00
#
#     eu_sales  jp_sales  other_sales  critic_score  user_score   rating  \
# ...

# %% [markdown]
# **Проделанная работа:**
#
# На протяжении проекта была проведена комплексная работа по подготовке и анализу данных об игровой индустрии за период 2000-2013 годов. Работа включала следующие ключевые этапы:
#
# **1. Изучение и предобработка данных:**
# - Загружен исходный датасет из 16,956 записей с 11 столбцами
# - Проведена диагностика качества данных, выявлены проблемы с типами данных и пропусками
# - Нормализованы названия столбцов к snake_case для удобства работы
# - Исправлены типы данных: преобразованы числовые столбцы из object в float64
# - Обработаны пропуски:
#   - Удалены 2 строки с отсутствующими названиями игр и жанрами
#   - Пропуски в продажах заменены на 0 (логическая интерпретация отсутствия продаж)
#   - Пропуски в рейтинге ESRB заменены на 'UNKNOWN'
#   - Пропуски в оценках сохранены для последующей категоризации
# - Устранены дубликаты:
#   - Нормализованы текстовые данные (регистр, устаревшие обозначения)
#   - Удалены 241 явный дубликат (1.43% от данных)
#
# **2. Фильтрация данных:**
# - Создан датафрейм `df_actual` с играми за период 2000-2013 гг.
# - Отфильтровано 12,781 игра, что составляет 75.4% от обработанного датасета
#
# **3. Категоризация данных:**
# - Созданы две системы категоризации оценок:
#   - **Пользовательские оценки** (шкала 0-10):
#     - Высокая: 8-10
#     - Средняя: 3-8
#     - Низкая: 0-3
#     - Не оценено: пропуски
#   - **Оценки критиков** (шкала 0-100):
#     - Высокая: 80-100
#     - Средняя: 30-80
#     - Низкая: 0-30
#     - Не оценено: пропуски
# - Выявлены топ-7 платформ по количеству выпущенных игр
#
# ### **Новые поля в датасете:**
#
# 1. **`user_score_category`** - категориальная переменная пользовательских оценок:
#    - `Высокая оценка`: игры с рейтингом 8-10
#    - `Средняя оценка`: игры с рейтингом 3-8
#    - `Низкая оценка`: игры с рейтингом 0-3
#    - `Не оценено`: игры без пользовательских оценок
#
# 2. **`critic_score_category`** - категориальная переменная оценок критиков:
#    - `Высокая оценка`: игры с рейтингом 80-100
#    - `Средняя оценка`: игры с рейтингом 30-80
#    - `Низкая оценка`: игры с рейтингом 0-30
#    - `Не оценено`: игры без оценок критиков
#
# ### **Ключевые статистические находки:**
#
# **Распределение платформ:**
# 1. **PS2** - 2,127 игр (лидер рынка)
# 2. **DS** - 2,120 игр
# 3. **WII** - 1,275 игр
# 4. **PSP** - 1,180 игр
# 5. **X360** - 1,121 игр
# 6. **PS3** - 1,087 игр
# 7. **GBA** - 811 игр
#
# **Качество оценок:**
# - **Пользовательские оценки:**
#   - 49.3% игр оценены пользователями
#   - Среди оцененных: 46.2% получили высокие оценки (≥8)
#   - Только 1.8% оцененных игр получили низкие оценки (<3)
#
# - **Оценки критиков:**
#   - 55.0% игр оценены критиками
#   - Среди оцененных: 23.6% получили высокие оценки (≥80)
#   - Только 0.8% оцененных игр получили низкие оценки (<30)
#
# ### **Выводы для компании "Секреты Темнолесья":**
#
# 1. **Данные готовы к анализу:** Предоставленный датасет успешно очищен, отфильтрован и структурирован для изучения развития игровой индустрии в период 2000-2013 годов.
#
# 2. **Платформенный ландшафт:** Доминирующими платформами были Sony (PS2, PS3, PSP) и Nintendo (DS, WII), что отражает конкуренцию между этими компаниями в указанный период.
#
# 3. **Проблема с полнотой данных:** Значительная часть игр (около 50%) не имеет оценок от пользователей или критиков, что следует учитывать при анализе качества игр.
#
# 4. **Качество продукции:** Среди оцененных игр преобладают продукты со средними и высокими оценками, что свидетельствует о в целом высоком качестве игровой продукции в исследуемый период.
#
# 5. **Рекомендации для дальнейшего анализа:**
#    - Изучить динамику выпуска игр по годам для выявления пиковых периодов
#    - Проанализировать региональные особенности продаж (Северная Америка, Европа, Япония)
#    - Исследовать корреляцию между оценками и коммерческим успехом игр
#    - Сравнить популярность жанров на разных платформах
#    - Проанализировать влияние возрастного рейтинга ESRB на продажи
#
# **Заключение:** Работа по подготовке данных успешно завершена. Полученный датасет `df_actual` с 12,781 записью и 13 столбцами полностью готов для проведения углубленного анализа развития игровой индустрии в начале XXI века. Все данные прошли тщательную проверку, очистку и структурирование, что обеспечивает высокое качество основы для принятия бизнес-решений.

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkGreen'>👌 Итоговый вывод написан в полном объеме.</font>

# %% [markdown]
# <font color='DarkBlue'><b>Заключительный комментарий ревьюера</b></font><br><br>
# <font color='DarkGreen'>👌 Анастасия, проект отлично структурирован и проработан.<br>Так держать и дальше!<br></font>
# <font color='Red'>🛠 Что нужно, что бы сделать проект лучше:</font><br>
# <font color='Red'>🛠 Сделать анализ причин не корректных данных в количественных столбцах. Провести анализ пропусков и их причин, сделать промежуточные выводы.</font><br>
# <font color='DarkMagenta'>👉 При исправлении ошибок и недочетов будут приобретены дополнительный опыт и навыки!</font><br>
# <font color='DarkGreen'>👌 Жду окончательный вариант! Успехов.</font>

# %% [markdown]
# <font color='DarkBlue'><b>Заключительный комментарий ревьюера 2</b></font><br><br>
# <font color='DarkGreen'>👌 Анастасия! Удалось справиться со всеми заданиями в проекте. Молодец! 😄 Спасибо за работу!<br>
# Входе выполнения проекта научились анализировать первичные данные, проводить предобработку датасета, фильтровать и категоризировать данные. </font><br>
# <font color='DarkGreen'>👌 Теперь, вперед за новыми знаниями и навыками! Удачи! 😉</font>
# ![image.png](attachment:image.png)
